# %%
import numpy as np
import pandas as pd

# %%
arr = np.array([1,2,3,4,5,6])

arr = np.insert(arr, 6, 10)
arr = np.insert(arr, 7, 100)

arr
# Out:
# array([  1,   2,   3,   4,   5,   6,  10, 100])

# %%
print(range(10))
# Out:
# range(0, 10)
